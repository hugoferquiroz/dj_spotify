# %%
import pandas as pd

# %%
datajack = pd.read_csv('./data/user_candidatos.csv')
datajack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 153 entries, 0 to 152
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        153 non-null    object
#  1   id                153 non-null    object
#  2   acousticness      153 non-null    float64
#  3   danceability      153 non-null    float64
#  4   duration_ms       153 non-null    int64
#  5   energy            153 non-null    float64
#  6   instrumentalness  153 non-null    float64
#  7   key               153 non-null    int64
#  8   liveness          153 non-null    float64
#  9   loudness          153 non-null    float64
#  10  mode              153 non-null    int64
#  11  speechiness       153 non-null    float64
#  12  tempo             153 non-null    float64
#  13  valence           153 non-null    float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 16.9+ KB

# %%
datawalter = pd.read_csv('./data/candidatos_top_walter.csv')
datawalter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        152 non-null    object
#  1   id                152 non-null    object
#  2   acousticness      152 non-null    float64
#  3   danceability      152 non-null    float64
#  4   duration_ms       152 non-null    int64
#  5   energy            152 non-null    float64
#  6   instrumentalness  152 non-null    float64
#  7   key               152 non-null    int64
#  8   liveness          152 non-null    float64
#  9   loudness          152 non-null    float64
#  10  mode              152 non-null    int64
#  11  speechiness       152 non-null    float64
#  12  tempo             152 non-null    float64
#  13  valence           152 non-null    float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 16.8+ KB

# %%
datacesar = pd.read_csv('./data/candidatos_top_cesar.csv')
datacesar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250 entries, 0 to 249
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        250 non-null    object
#  1   id                250 non-null    object
#  2   acousticness      250 non-null    float64
#  3   danceability      250 non-null    float64
#  4   duration_ms       250 non-null    int64
#  5   energy            250 non-null    float64
#  6   instrumentalness  250 non-null    float64
#  7   key               250 non-null    int64
#  8   liveness          250 non-null    float64
#  9   loudness          250 non-null    float64
#  10  mode              250 non-null    int64
#  11  speechiness       250 non-null    float64
#  12  tempo             250 non-null    float64
#  13  valence           250 non-null    float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 27.5+ KB

# %%
datahugo = pd.read_csv('./data/candidatos_top_hugo.csv', sep='|')
datahugo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1068 entries, 0 to 1067
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1068 non-null   object
#  1   id                1068 non-null   object
#  2   acousticness      1068 non-null   float64
#  3   danceability      1068 non-null   float64
#  4   duration_ms       1068 non-null   int64
#  5   energy            1068 non-null   float64
#  6   instrumentalness  1068 non-null   float64
#  7   key               1068 non-null   int64
#  8   liveness          1068 non-null   float64
#  9   loudness          1068 non-null   float64
#  10  mode              1068 non-null   int64
#  11  speechiness       1068 non-null   float64
#  12  tempo             1068 non-null   float64
#  13  valence           1068 non-null   float64
# dtypes: float64(9), int64(3), object(2)
# memory usage: 116.9+ KB

# %%
data = pd.concat([datajack, datawalter, datacesar, datahugo], axis=0, ignore_index=True)

# %%
data
# Out:
#                          Unnamed: 0                      id  acousticness  \
# 0         Estoy a la Puerta y Llamo  4bjsp9L4sWREYUkZU8nc6e        0.9350
# 1                     Nada Te Turbe  7GPBx7jwkMSnlUS6Qqudlp        0.8590
# 2                           Entraré  1koXbetRP1PgmDRqU4DFPb        0.9440
# 3                 Someone You Loved  7qEHsqek33rTcFNT9PFqLf        0.7510
# 4                     Before You Go  2gMXnyrvIjhVBUZwvLZDMP        0.6040
# ...                             ...                     ...           ...
# 1618                      Serás mía  4omW8SyhcPp33OGXcVLuYS        0.2490
# 1619  Serás mía (Versión reggaetón)  0iEKRsvXgzrAsGS0t2z3VT        0.0254
# 1620                    Mix Pandora  1WaAULqylFyLty4I3sup98        0.4070
# 1621           Cuando un Amor Se Va  38pMwrjp5fGNlVE1plB5Mi        0.4570
# 1622                 Morenita Linda  4Iwshe7JZJjwcdNXODAlel        0.1710
#
#       danceability  duration_ms  energy  instrumentalness  key  liveness  \
# 0            0.493       198240  0.1120          0.000558   10    0.1630
# 1            0.523       216054  0.2420          0.000072    0    0.1050
# 2            0.426       262373  0.0559          0.000000    7    0.0633
# 3            0.501       182161  0.4050          0.000000    1    0.1050
# 4            0.459       215107  0.5750          0.000000    3    0.0885
# ...            ...          ...     ...               ...  ...       ...
# 1618         0.460       181888  0.5700          0.000000    5    0.1320
# 1619         0.746       188277  0.8290          0.000004    5    0.1090
# 1620         0.736       265509  0.7410          0.000026    2    0.0304
# 1621         0.755       223869  0.9440          0.006600    2    0.0260
# 1622         0.777       235285  0.8540          0.000003    4    0.0717
#
#       loudness  mode  speechiness    tempo  valence
# 0      -14.419     0       0.0345   76.480    0.243
# 1       -9.303     1       0.0269  103.928    0.319
# 2      -18.357     1       0.0300   71.843    0.116
# 3       -5.679     1       0.0319  109.891    0.446
# 4       -4.858     1       0.0573  111.881    0.183
# ...        ...   ...          ...      ...      ...
# 1618    -5.459     1       0.0300   85.144    0.416
# 1619    -5.399     1       0.0556   98.010    0.669
# 1620    -3.897     1       0.0448  106.956    0.817
# 1621    -3.457     1       0.0337  101.523    0.909
# 1622    -4.511     0       0.0383  104.972    0.577
#
# [1623 rows x 14 columns]

# %%
data.tail()
# Out:
#                                             Unnamed: 0  \
# 550                                          Moonlight
# 551                                            Melting
# 552                                          telepatía
# 553                                   I Wish you Roses
# 554  After The Storm (feat. Tyler, The Creator & Bo...
#
#                          id  acousticness  danceability  duration_ms  energy  \
# 550  0JmnkIqdlnUzPaf8sqBRs3         0.518         0.642       187723   0.706
# 551  2kSb3wYSOV996xA2NSmpck         0.179         0.574       208854   0.479
# 552  6tDDoYIxWvMLTdKpjFkc1B         0.112         0.653       160191   0.524
# 553  35SbrfbaSpGUBX7e5BPega         0.180         0.452       219955   0.589
# 554  1otG6j1WHNvl9WgXLWkHTo         0.301         0.702       207455   0.659
#
#      instrumentalness  key  liveness  loudness  mode  speechiness    tempo  \
# 550           0.00000    7     0.250    -6.872     0       0.0520  136.851
# 551           0.08030    8     0.106    -7.776     1       0.0355  115.263
# 552           0.00000   11     0.203    -9.016     0       0.0502   83.970
# 553           0.00048   10     0.139    -8.371     0       0.0458  141.692
# 554           0.00201    4     0.218    -6.766     0       0.1300   79.640
#
#      valence
# 550    0.896
# 551    0.303
# 552    0.553
# 553    0.315
# 554    0.843

# %%
# data.reset_index(drop=False, inplace=True)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1623, step=1)

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'id', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'valence'],
#       dtype='object')

# %%
data.set_index('Unnamed: 0', inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 555 entries, Estoy a la Puerta y Llamo to After The Storm (feat. Tyler, The Creator & Bootsy Collins)
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                555 non-null    object
#  1   acousticness      555 non-null    float64
#  2   danceability      555 non-null    float64
#  3   duration_ms       555 non-null    int64
#  4   energy            555 non-null    float64
#  5   instrumentalness  555 non-null    float64
#  6   key               555 non-null    int64
#  7   liveness          555 non-null    float64
#  8   loudness          555 non-null    float64
#  9   mode              555 non-null    int64
#  10  speechiness       555 non-null    float64
#  11  tempo             555 non-null    float64
#  12  valence           555 non-null    float64
# dtypes: float64(9), int64(3), object(1)
# memory usage: 60.7+ KB

# %%
data.to_csv('data/datadmc.csv')
